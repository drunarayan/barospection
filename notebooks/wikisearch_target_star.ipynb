# %% [markdown]
# ### WIKI Search Target

# %%
#pip install --upgrade astropy astroquery googlesearch-python wikipedia pandas

# %%
# importing the module
import wikipedia as wiki
from IPython.display import Markdown as md

# %%
import requests
import webbrowser
from bs4 import BeautifulSoup

# %%
def wikisearchurl(tname):
    # 1. Define the Wikipedia URL
    #url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
    url = f"https://en.wikipedia.org/w/index.php?search={tname}&title=Special%3ASearch&fulltext=1&ns0=1"

    # 2. Fetch the page with a User-Agent to avoid 403 Forbidden errors
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)

    # 3. Check for successful request and parse HTML
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # 4. Find all <a> tags with an 'href' attribute
        # Filters: starts with '/wiki/' and does not contain a ':'
        wiki_links = []
        for link in soup.find_all('a', href=True):
            href = link['href']
            if href.startswith('/wiki/') and ':' not in href:
                full_url = f"https://en.wikipedia.org{href}"
                wiki_links.append(full_url)

        # 5. Display the first 10 extracted URLs
        print(*wiki_links[:10], sep="\n")
        print("\nExamine these results above and click any related links ...\n")

# %%
from IPython.display import Markdown as md
itn = "STOP"
target_name = input(f"Enter Star Name: [{itn}]: ") or f"{itn}"
while target_name != itn:
    print(f"You typed the Star name: {target_name}")
    md(f"### Obtain details for target star {target_name}")
    wikisearchurl(target_name)
    target_name = input(f"Enter Star Name: [{itn}]: ") or f"{itn}"
exit
# Out:
# Enter Star Name: [STOP]:  fghk
# You typed the Star name: fghk
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/FGH
# https://en.wikipedia.org/wiki/Forest_Grove_High_School
# https://en.wikipedia.org/wiki/Forest_Grove_High_School
# https://en.wikipedia.org/wiki/FGHS
# https://en.wikipedia.org/wiki/Newt_Gingrich
# https://en.wikipedia.org/wiki/Newt_Gingrich
# https://en.wikipedia.org/wiki/FGH_Publications
# https://en.wikipedia.org/wiki/Ackermann_function
#
# Examine these results above and click any related links ...
# Enter Star Name: [STOP]:  dflgj
# You typed the Star name: dflgj
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/DragonFly_BSD
# https://en.wikipedia.org/wiki/DragonFly_BSD
# https://en.wikipedia.org/wiki/Dfly
# https://en.wikipedia.org/wiki/DragonFLY
# https://en.wikipedia.org/wiki/DragonFLY
# https://en.wikipedia.org/wiki/DFLY
# https://en.wikipedia.org/wiki/DF
# https://en.wikipedia.org/wiki/Diaza-2C-DFLY
#
# Examine these results above and click any related links ...
# Enter Star Name: [STOP]:
