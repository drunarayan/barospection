# %%
#%pip install requests beautifulsoup4

# %%
#%pip install git+https://github.com/abenassi/Google-Search-API

# %%
import requests
import webbrowser
from bs4 import BeautifulSoup
# Out:
# /Users/druyan/opt/anaconda3/lib/python3.9/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (4.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# ### Decode Blind ID and Explore your Star!

# %%
def decode_two_integers(encoded_int, bit_shift):
    """
    Decodes a single integer back into two original integers.

    Args:
        encoded_int (int): The encoded integer.
        bit_shift (int): The same bit_shift used during encoding.

    Returns:
        tuple: A tuple containing the two original integers (int1, int2).
    """
    int1 = encoded_int >> bit_shift
    int2 = encoded_int & ((1 << bit_shift) - 1) # Mask to get the lower bits
    return int1, int2

# Example usage:
#num_a = 596
#num_b = 728

shift_amount = 10 # Assuming num_b will fit within 10 bits

def wikisearchurl(tname):
    # 1. Define the Wikipedia URL
    #url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
    url = f"https://en.wikipedia.org/w/index.php?search={tname}&title=Special%3ASearch&fulltext=1&ns0=1"

    # 2. Fetch the page with a User-Agent to avoid 403 Forbidden errors
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)

    # 3. Check for successful request and parse HTML
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # 4. Find all <a> tags with an 'href' attribute
        # Filters: starts with '/wiki/' and does not contain a ':'
        wiki_links = []
        for link in soup.find_all('a', href=True):
            href = link['href']
            if href.startswith('/wiki/') and ':' not in href:
                full_url = f"https://en.wikipedia.org{href}"
                wiki_links.append(full_url)

        # 5. Display the first 10 extracted URLs
        print(*wiki_links[:10], sep="\n")
        print("\nExamine these results above and click any related links ...\n")
        print("\nWhen all else has failed Open Google Search by executing next cell!")
        
def wikihdsearch(tname):
    # 1. Define the Wikipedia URL
    #url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
    url = f"https://en.wikipedia.org/wiki/{tname}"

    # 2. Fetch the page with a User-Agent to avoid 403 Forbidden errors
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)

    # 3. Check for successful request and parse HTML
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # 4. Find all <a> tags with an 'href' attribute
        # Filters: starts with '/wiki/' and does not contain a ':'
        wiki_links = []
        for link in soup.find_all('a', href=True):
            href = link['href']
            if href.startswith('/wiki/Main_Page') and ':' not in href:
                full_url = f"https://en.wikipedia.org{href}"
                wiki_links.append(full_url)

        # 5. Display the first 10 extracted URLs
        print(*wiki_links[:10], sep="\n")
        print("\nExamine these results above and click any related links ...\n")
        print("\nIf star not found try a broader wiki search by executing next cell!")

# %%
for ibid in 443096, 11019992, 158624472, 167996120, 180672216, 198751960, \
201292504, 207306456, 208170712, 214486744, 214784728, 214825688, \
215468760, 216509144, 223121112, 225343192:
    bid = input(f"Enter BID number by itself [{ibid}]: ") or f"{ibid}"
    print(f"The Blind ID is: {bid}")
    hd, x, = decode_two_integers(int(bid), shift_amount)
    print(f"You have successfully decoded HD Catalog number for your Star: HD {hd}")
    print(f"\nExplore HD{hd} using links below\n")
    print(f"Attempting specific HD catalog search ...")
    tname = f"HD_{hd}"
    wikihdsearch(tname)
    tname = f"HD {hd}"
    wikisearchurl(tname)
# Out:
# Enter BID number by itself [443096]:
# The Blind ID is: 443096
# You have successfully decoded HD Catalog number for your Star: HD 432
#
# Explore HD432 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
#
# Examine these results above and click any related links ...
#
#
# If star not found try a broader wiki search by executing next cell!
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/HD_432
# https://en.wikipedia.org/wiki/Beta_Cassiopeiae
# https://en.wikipedia.org/wiki/Beta_Cassiopeiae
# https://en.wikipedia.org/wiki/HD_432
# https://en.wikipedia.org/wiki/List_of_Redmi_products
# https://en.wikipedia.org/wiki/DCI-P3
# https://en.wikipedia.org/wiki/DCI-P3
# https://en.wikipedia.org/wiki/SMPTE_EG_432-1
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [11019992]:
# The Blind ID is: 11019992
# You have successfully decoded HD Catalog number for your Star: HD 10761
#
# Explore HD10761 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Omicron_Piscium
# https://en.wikipedia.org/wiki/Omicron_Piscium
# https://en.wikipedia.org/wiki/List_of_stars_in_Pisces
# https://en.wikipedia.org/wiki/Lili_Marleen
# https://en.wikipedia.org/wiki/Lili_Marleen
# https://en.wikipedia.org/wiki/Placenta-specific_protein_1
# https://en.wikipedia.org/wiki/Placenta-specific_protein_1
# https://en.wikipedia.org/wiki/Lego_Super_Heroes
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [158624472]:
# The Blind ID is: 158624472
# You have successfully decoded HD Catalog number for your Star: HD 154906
#
# Explore HD154906 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Mu_Draconis
# https://en.wikipedia.org/wiki/Mu_Draconis
# https://en.wikipedia.org/wiki/List_of_stars_in_Draco
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [167996120]:
# The Blind ID is: 167996120
# You have successfully decoded HD Catalog number for your Star: HD 164058
#
# Explore HD164058 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Gamma_Draconis
# https://en.wikipedia.org/wiki/Gamma_Draconis
# https://en.wikipedia.org/wiki/List_of_stars_in_Draco
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [180672216]:
# The Blind ID is: 180672216
# You have successfully decoded HD Catalog number for your Star: HD 176437
#
# Explore HD176437 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Gamma_Lyrae
# https://en.wikipedia.org/wiki/Gamma_Lyrae
# https://en.wikipedia.org/wiki/List_of_stars_in_Lyra
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [198751960]:
# The Blind ID is: 198751960
# You have successfully decoded HD Catalog number for your Star: HD 194093
#
# Explore HD194093 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Gamma_Cygni
# https://en.wikipedia.org/wiki/Gamma_Cygni
# https://en.wikipedia.org/wiki/List_of_stars_in_Cygnus
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [201292504]:
# The Blind ID is: 201292504
# You have successfully decoded HD Catalog number for your Star: HD 196574
#
# Explore HD196574 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
#
# Examine these results above and click any related links ...
#
#
# If star not found try a broader wiki search by executing next cell!
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/HD_196574
# https://en.wikipedia.org/wiki/71_Aquilae
# https://en.wikipedia.org/wiki/71_Aquilae
# https://en.wikipedia.org/wiki/HD_196574
# https://en.wikipedia.org/wiki/List_of_stars_in_Aquila
# https://en.wikipedia.org/wiki/HD_194013
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [207306456]:
# The Blind ID is: 207306456
# You have successfully decoded HD Catalog number for your Star: HD 202447
#
# Explore HD202447 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Alpha_Equulei
# https://en.wikipedia.org/wiki/Alpha_Equulei
# https://en.wikipedia.org/wiki/List_of_stars_in_Equuleus
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [208170712]:
# The Blind ID is: 208170712
# You have successfully decoded HD Catalog number for your Star: HD 203291
#
# Explore HD203291 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/List_of_stars_in_Equuleus
# https://en.wikipedia.org/wiki/9_Equulei
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [214486744]:
# The Blind ID is: 214486744
# You have successfully decoded HD Catalog number for your Star: HD 209459
#
# Explore HD209459 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/List_of_stars_in_Pegasus
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [214784728]:
# The Blind ID is: 214784728
# You have successfully decoded HD Catalog number for your Star: HD 209750
#
# Explore HD209750 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
#
# Examine these results above and click any related links ...
#
#
# If star not found try a broader wiki search by executing next cell!
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/HD_209750
# https://en.wikipedia.org/wiki/Alpha_Aquarii
# https://en.wikipedia.org/wiki/Alpha_Aquarii
# https://en.wikipedia.org/wiki/HD_209750
# https://en.wikipedia.org/wiki/List_of_stars_in_Aquarius
# https://en.wikipedia.org/wiki/HD_219279
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [214825688]:
# The Blind ID is: 214825688
# You have successfully decoded HD Catalog number for your Star: HD 209790
#
# Explore HD209790 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Xi_Cephei
# https://en.wikipedia.org/wiki/Xi_Cephei
# https://en.wikipedia.org/wiki/List_of_stars_in_Cepheus
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [215468760]:
# The Blind ID is: 215468760
# You have successfully decoded HD Catalog number for your Star: HD 210418
#
# Explore HD210418 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Theta_Pegasi
# https://en.wikipedia.org/wiki/Theta_Pegasi
# https://en.wikipedia.org/wiki/List_of_stars_in_Pegasus
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [216509144]:
# The Blind ID is: 216509144
# You have successfully decoded HD Catalog number for your Star: HD 211434
#
# Explore HD211434 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
#
# Examine these results above and click any related links ...
#
#
# If star not found try a broader wiki search by executing next cell!
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/HD_211434
# https://en.wikipedia.org/wiki/44_Aquarii
# https://en.wikipedia.org/wiki/HD_211434
# https://en.wikipedia.org/wiki/List_of_stars_in_Aquarius
# https://en.wikipedia.org/wiki/HD_219279
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [223121112]:
# The Blind ID is: 223121112
# You have successfully decoded HD Catalog number for your Star: HD 217891
#
# Explore HD217891 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Beta_Piscium
# https://en.wikipedia.org/wiki/Beta_Piscium
# https://en.wikipedia.org/wiki/List_of_stars_in_Pisces
# https://en.wikipedia.org/wiki/Results_of_the_2014_Indian_general_election
# https://en.wikipedia.org/wiki/Results_of_the_2014_Indian_general_election
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!
# Enter BID number by itself [225343192]:
# The Blind ID is: 225343192
# You have successfully decoded HD Catalog number for your Star: HD 220061
#
# Explore HD220061 using links below
#
# Attempting specific HD catalog search ...
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Tau_Pegasi
# https://en.wikipedia.org/wiki/Tau_Pegasi
# https://en.wikipedia.org/wiki/List_of_stars_in_Pegasus
#
# Examine these results above and click any related links ...
#
#
# When all else has failed Open Google Search by executing next cell!

# %%
if not bid==-1:
    url = f'http://www.google.com/search?q={tname} Astronomy'
    webbrowser.open(url)
