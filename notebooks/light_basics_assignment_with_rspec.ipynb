# %% [markdown]
# # What are light and matter and how do they interact with each other?

# %% [markdown]
# How is it possible to figure out such detailed information about materials on Earth and in space based only on color? Spectroscopy works because light and matter interact with each other in very specific and predictable ways. Let’s review some relevant basics about light and matter.

# %% [markdown]
# <div class="alert alert-success">Spectroscopy works because light and matter interact with each other in very specific and predictable ways.</div>

# %% [markdown]
# ## Light (or Electromagnetic Waves!!)

# %% [markdown]
# Gamma rays, X-rays, ultraviolet light, visible light (the visible rainbow), infrared light, microwaves, and radio waves are all forms of light, also called electromagnetic radiation. Together, they make up the electromagnetic spectrum. (That’s right, the radio waves that carry music from the station to your radio, the microwaves that heat up your food, and the X-rays dentists use to detect tooth decay are all forms of light.)
#
# Light has a number of fascinating (and somewhat odd) characteristics that are important for spectroscopy.

# %% [markdown]
# ![ElectromagneticSpectrum.jpg](attachment:f5177aa6-6d6a-4379-aa9a-be00e4dc04f1.jpg)

# %% [markdown]
# Gamma rays, X-rays, ultraviolet light, visible light (the visible rainbow), infrared light, microwaves, and radio waves are all forms of light, also called electromagnetic radiation. Together, they make up the electromagnetic spectrum. Each band of light has a different range of wavelengths: Gamma rays are the shortest and radio waves are the longest.  Notice that the visible wavelengths - **Light** (for humans) make up a very tiny part of the entire Electromagnetic Spectrum.

# %% [markdown]
# **Waves**
#
# ***Light behaves like a wave***. You are probably familiar with waves: water waves that ripple across a pond, sound waves that vibrate air and ear drums, and seismic (earthquake) waves that cause the ground to shake. These are all mechanical waves—energy that propagates through matter, causing it to move up and down, back and forth, or side to side.
#
# Light waves are similar, but while mechanical waves cause oscillations in matter, light waves consist of electric and magnetic fields oscillating perpendicular to each other. Mechanical waves need matter in order to propagate, but light waves can travel through completely empty space as well as through matter.

# %% [markdown]
# 2D Wave|3D Wave
# ---|---|
# ![MechanicalWave_v2.jpg](attachment:3072c3fe-6b32-4e51-83be-a130bb51c769.jpg)|![ElectromagneticWave_v2.jpg](attachment:fa721339-fb9f-4853-b0a7-e4ea63494621.jpg)
# A mechanical wave is a propagation of energy through matter. The wavelength is the distance between two consecutive peaks (the highest part of the wave) or troughs (the lowest part of the wave). On this graph, the x-axis is distance and the y-axis is the displacement of matter.|Light waves involve oscillations of electric and magnetic fields rather than oscillations of matter. The wavelength is its color. On this graph the x-axis is distance; the y-axis is the strengh of the electric field; and the z-axis is the strength of the magnetic field.

# %% [markdown]
# One way to measure waves is by their wavelength. Wavelength is the distance between successive peaks. The wavelength of a light wave is the distance between peaks in the electric and magnetic fields.

# %% [markdown]
# ![light basics](https://openstax.org/apps/archive/20240625.161426/resources/8caecaac580f639ebf6ba550db228a684da01ca6)

# %% [markdown]
# While that definition might make it sound like wavelength is a property that only a physicist could appreciate, most people are actually very familiar with the concept of wavelength: Human eyes recognize differences in wavelength as differences in color. On the visible part of the spectrum, shorter wavelengths look bluer and longer wavelengths look redder.

# %% [markdown]
# Wavelength is also what differentiates the various bands of light on the electromagnetic spectrum. When people talk about different “types” of light, they are referring to broad differences in wavelength. Gamma rays have the shortest wavelengths and radio waves have the longest. Visible light is in the middle. You can think of gamma rays, X-rays, ultraviolet light, infrared light, microwaves, and radio waves as bands of invisible color.

# %% [markdown]
# ![Prism.jpg](attachment:9275d415-c836-4250-8922-5c769f83349e.jpg)

# %% [markdown]
# Sunlight that passes through a prism naturally separates into its component colors in a very specific order—rainbow order—based on wavelength. This rainbow is known as the visible spectrum. In addition to visible light, sunlight also contains significant amounts of infrared and ultraviolet light, both of which are invisible to human eyes.

# %% [markdown]
# <div class="alert alert-success">Human eyes recognize differences in wavelength as differences in color.</div>

# %% [markdown]
# ## Particles (are Waves too?)

# %% [markdown]
# ***Light also behaves like a particle***. A particle of light is called a ***photon***. Each individual photon has a very specific amount of energy (no more, no less), which corresponds to its wavelength. Blue photons carry more energy than red photons. Ultraviolet photons carry more energy than infrared photons. Sometimes photons are described as “packets of energy.”
#
# So, you can think of light as waves or you can think of it as streams of photons. Astronomers use both terms, depending on what they are trying to study or explain. (If you are confused as to how light can be both a particle and a wave at the same time, don’t despair. You are not alone.)
#
# The important thing to keep in mind when it comes to spectroscopy is that ***wavelength (or frequency) and energy are effectively the same thing***. Human eyes detect differences in wavelength and energy as differences in color.

# %% [markdown]
# ![STScI-J-article-Spectroscopy-Part2-WavelengthAndEnergy.jpg](attachment:0c045820-b81d-4835-89dc-08378ad1f3fd.jpg)

# %% [markdown]
# Different colors of light have different wavelengths and energy. Light toward the red end of the spectrum has longer wavelengths and lower energy than light toward the violet end of the spectrum. Infrared light has even longer wavelengths than red; while ultraviolet has even shorter wavelengths than violet. Wavelength is described in units of length. Ultraviolet, visible, and infrared light are typically given in microns (µm), nanometers (nm), or ångstroms (Å).
#
# <div class="alert alert-success">Note: 1 Å =  $10^{-10}$ m where 1 Å =  $10^{-10}$ m or 0.1 nm. The hydrogen atom is approximately 1 Å in diameter!</div>

# %% [markdown]
# ### <div class="alert alert-info">🔵 Let us do some simple calculations</div>
# ### Whereever you see ???? that is a prompt for you to provide input in the form of markdown syntax (inside Markdown cells), LaTeX syntax (inside Markdown cells), or Python (inside Code cells). See above on the menu bar to see what type of cell it is. To find examples, simply double-click a cell to see how I did it!!  Once you complete a notebook, save it one last time, that's all you have to do, it is "submitted". I will be able to see it.

# %% [markdown]
# ### <div class="alert alert-info">🔵 What is the wavelength of light that has a frequency of  457.1 TeraHz?  The speed of light is 300,000 km/s. Provide your answer by creating & calculating variables below:</div>

# %% [markdown]
# ### $c = \lambda f$ OR $\lambda = {{c}\over{f}}$
#
# ### where $c$ is the *speed* of the wave in $m\over{s}$,
#
# ### $\lambda$ is *wavelength* in $m$, and
#
# ### $f$ is in ${hz}$ which has units of $1\over{s}$

# %%
f = ???? # Tera Hz
c = ???? # m/s
lam = c/f
print(f'The wavelength of light that has a frequency of {f:.3e} Hz is {lam:4.3e} m')
print(f'This wavelength can also expressed as {w*1e10*u.angstrom:.4e} or {w*1e9*u.nanometer:.3e}')
print(f'This happens to be the wavelength of the Hydrogen Alpha emission/absorption!')
# Out:
# The wavelength of light that has a frequency of 4.571e+14 Hz is 6.563e-07 m
# This wavelength can also expressed as 6.5631e+03 Angstrom or 6.563e+02 nm
# This happens to be the wavelength of the Hydrogen Alpha emission/absorption!

# %% [markdown]
# ## Discovery of Spectral Lines

# %% [markdown]
# The existence of the solar spectrum was known ***since 1666 when Newton used a prism to produce a rainbow of colors from sunlight*** in a darkened room using a prism.
#
# Later ***in 1786 David Rittenhouse, an American astronomer, first made a primitive  grating*** (a glass plate with very fine lines scored on it) to produce the same rainbow of colors.
#
# In ***1802 William Hyde Wollaston (English Scientist) observes dark line spectra*** of the sun.
#
# Significantly, ***in 1814 - Joseph von Frauenhofer (German optician) invents the transmission diffraction grating*** and undertakes a systematic study of dark lines in the solar spectrum. This work serves as the foundation for the science of astrophysics.
#
# ***1826 - William Henry Fox Talbot*** observes that different salts produce colours when placed in a flame.
#
# ***1859 - Gustav Robert Kirchoff (German physicist) & Robert Bunsen (German chemist)*** show spectral lines are unique to each element, thus ***founding the science of spectral analysis as a tool for studying the composition of matter***.
#
# ***In 1885 Johann Balmer*** was looking for numerical relationships among the wavelengths that had been observed for lines in the spectrum of hydrogen. The four spectral lines known in the ***visible spectrum had wavelengths of 6562.10, 4860.74, 4340.1, and 4101.2 Å***.
#
#
# ![hyd_spec.png](attachment:2ce63988-6725-4b99-9bac-8025d7363729.png)
#
# Balmer found that these four wavelengths fit a pattern that he expressed in the following formula
#
# ***$ \lambda = B \times {m^2 \over {m^2 - n^2}} $***
#
# where B is the same constant for all four lines and where m takes on whole-number values greater than 2 (that is, m = 3, 4, 5, and 6 respectively for the four lines in the visible spectrum).

# %% [markdown]
# Bohr Model|Transition from Level 3 to 2
# ---|---|
# ![Bohr_atom_model.svg.png](attachment:ead54ea4-5b4e-4341-8828-d230114d6c18.png)|![bm](https://upload.wikimedia.org/wikipedia/commons/3/31/Bohr_atom_animation.gif)

# %% [markdown]
# ![jumps](jumps.png)

# %% [markdown]
# # [Light Wavelength Frequency and Speed](https://openstax.org/books/astronomy-2e/pages/5-1-the-behavior-of-light)

# %% [markdown]
# ![em](https://openstax.org/apps/archive/20240625.161426/resources/fd686395fdb767eb21ed9f677d202e5b639293db)

# %% [markdown]
# ![Screenshot 2024-07-18 at 6.52.56 PM.png](attachment:d8831567-d427-4bd1-8d34-f8d39e4701b7.png)

# %% [markdown]
# # [Radiation, Temperature & Blackbodies](https://openstax.org/books/astronomy-2e/pages/5-2-the-electromagnetic-spectrum)
# Some astronomical objects emit mostly infrared radiation, others mostly visible light, and still others mostly ultraviolet radiation. What determines the type of electromagnetic radiation emitted by the Sun, stars, and other dense astronomical objects? The answer often turns out to be their temperature.
#
# At the microscopic level, everything in nature is in motion. A solid is composed of molecules and atoms in continuous vibration: they move back and forth in place, but their motion is much too small for our eyes to make out. A gas consists of atoms and/or molecules that are flying about freely at high speed, continually bumping into one another and bombarding the surrounding matter. The hotter the solid or gas, the more rapid the motion of its molecules or atoms. The temperature of something is thus a measure of the average motion energy of the particles that make it up.
#
# This motion at the microscopic level is responsible for much of the electromagnetic radiation on Earth and in the universe. As atoms and molecules move about and collide, or vibrate in place, their electrons give off electromagnetic radiation. The characteristics of this radiation are determined by the temperature of those atoms and molecules. In a hot material, for example, the individual particles vibrate in place or move rapidly from collisions, so the emitted waves are, on average, more energetic. And recall that higher energy waves have a higher frequency. In very cool material, the particles have low-energy atomic and molecular motions and thus generate lower-energy waves.

# %% [markdown]
# A black body is an idealized object that absorbs all electromagnetic radiation it comes in contact with. It then emits thermal radiation in a continuous spectrum according to its temperature. Stars behave approximately like blackbodies, and this concept explains why there are different colors of stars. See the figure below.

# %% [markdown]
# ![Screenshot 2024-07-18 at 6.55.09 PM.png](attachment:81309d62-5a05-45cd-88a6-ccac4bb43409.png)

# %% [markdown]
# <div class="alert alert-warning"> 🔵 Now let us calibrate the BARO spectral grating using a Type A star and draw 2 SED (Spectral Energy Distrubution) curves, one Type A star of your choosing and second your assigned star.</div>
#
# #### To do this assignment fully, you might need to watch this video - [Mr Tom Field's 3. Calibrating your Spectrum Video on the Rspec website](https://rspec-astro.com/more-videos/).
#
# 1. Follow instructions and Calibrate the BARO grating by choosing a Type A Star, downloading it to your Windows laptop, and drag drop it into the RSpec panel for analysis. Follow all directions. You will be using the ````2-point-alignment Calibration```` process. When you have a fully calibrated spectrum, capture a screen shot as a jpeg or png file - rename the file without any spaces on the file name (for example rename it "calibrated_sprectrum.png"). Make sure that the screen shot contains the file name at the top bar showing the star name and type! Then simply drag and drop the screenshot file "calibrated_sprectrum.png" into the left panel. Then YOUR OWN image should show up below when this cell is "executed" (press shift-enter from edit mode). Make a note of YOUR dispersion (angstroms per pixel) value.  YOUR own image of the analyzed spectrum should show up below NOT mine!!
#     * ![](calibrated_spectrum.png)
#
# 1. Once you have noted YOUR dispersion value, you are ready to move on to the second step.  Now you should choose a non-Type A star (types O, B, F, G or K). Download that to you laptop and as before drag and drop it into RSpec. Now, you will use the ````one-point-alignment```` calibration process discussed in the video. The zero-order point is the only one needed with the dispersion value entered as shown.  Now each type of Star has certain element lines prominently visible due to the various quantum effects at play. We wil discuss these in our next session. In the meanwhile **[you can use my google search](https://docs.google.com/document/d/18sKEnredkevdc27HZJm_0Ks_ZcezA_Mg5bKIaqvfyUM/edit?usp=sharing)** that describes what lines should be prominent for the type of star you have chosen.  Carefully read the google search extract above to see if you can identify specific element lines in your star and highlight them by annotating your image or writing a few words about the lines in text form. Once you have done that use the same steps as you did previously to capture a second screen shot named without spaces (for example rename it "analyzed_spectrum.png"). Make sure that the screen shot contains the file name at the top bar showing the star name and type! Then YOUR OWN image of the analyzed spctrum should show up below when this cell is "executed" (press shift-enter from edit mode). YOUR image of the spectral analysis of the second star should show up below NOT mine!!
#     * ![](analyzed_spectrum.png)

# %% [markdown]
# ###  That's it you are ✅ DONE! Save your Jupyter notebook.
