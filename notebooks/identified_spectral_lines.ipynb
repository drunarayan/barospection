# %% [markdown]
# # Identified Spectral Lines in Calibration Star XXXX

# %% [markdown]
# <div class="alert alert-success">Add an image from RSpec showing your ***Calibration*** star and annotated Spectral Lines that you identified using the <a href="http://www.astrosurf.com/heidemann/spectroscopie/spectroscopic_atlas_walker_4.pdf" download="spectroscopic_atlas_walker_4.pdf" rel="noopener" target="_blank">Walker Spectroscopic Atlas</a>|</div>

# %% [markdown]
# ![Calibration Star XXXX](annotated_calibration_star.png)

# %% [markdown]
# # Identified Spectral Lines in Assigned Star XXXX

# %% [markdown]
# <div class="alert alert-success">Add an image from RSpec showing your ***Assigned*** star and annotated Spectral Lines that you identified using the <a href="http://www.astrosurf.com/heidemann/spectroscopie/spectroscopic_atlas_walker_4.pdf" download="spectroscopic_atlas_walker_4.pdf" rel="noopener" target="_blank">Walker Spectroscopic Atlas</a>|</div>

# %% [markdown]
# ![Calibration Star XXXX](annotated_calibration_star.png)
